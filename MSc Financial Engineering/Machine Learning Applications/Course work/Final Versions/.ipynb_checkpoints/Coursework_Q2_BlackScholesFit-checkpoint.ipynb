# %% [markdown]
# # Deep Learning Black Scholes using TensorFlow
# The goal of this case study is to perform derivative pricing from a machine learning standpoint and use supervised regression-based model to learn the Black-Scholes option pricing model from simulated data.

# %% [markdown]
# <a id='0'></a>
# # 1. Problem Definition

# %% [markdown]
# In the supervised regression framework used for this case study, the derivative pricing
# problem is defined in the regression framework, where the predicted variable is the
# pricing of the option, and the predictor variables are the market data that are used as
# inputs to the Black-Scholes option pricing model

# %% [markdown]
# Options have been used in finance as means to hedge risk in a nonlinear manner. They are are also used by speculators in order to take leveraged bets in the financial markets. Historically, people have used the Black Scholes formula.

# %% [markdown]
# $$  Se^{-q \tau}\Phi(d_1) - e^{-r \tau} K\Phi(d_2) \, $$

# %% [markdown]
# With

# %% [markdown]
# $$  d_1 = \frac{\ln(S/K) + (r - q + \sigma^2/2)\tau}{\sigma\sqrt{\tau}}  $$

# %% [markdown]
# and

# %% [markdown]
# $$  d_2 = \frac{\ln(S/K) + (r - q - \sigma^2/2)\tau}{\sigma\sqrt{\tau}} = d_1 - \sigma\sqrt{\tau}  $$

# %% [markdown]
# Where we have;
#     Stock price $S$;
#     Strike price $K$;
#     Risk-free rate $r$;
#     Annual dividend yield $q$;
#     Time to maturity $\tau = T-t$ (represented as a unit-less fraction of one year);
#     Volatility $\sigma$

# %% [markdown]
# In order to make the logic simpler, we define *Moneyness* as $M = K/S$ and look at the prices in terms of per unit of current stock price. We also set $q$ as $0$

# %% [markdown]
# This simplifes the formula down to the following

# %% [markdown]
# $$  S e^{-q \tau}\Phi\left( \frac{- \ln(M) + (r+ \sigma^2/2 )\tau}{\sigma\sqrt{\tau}}\right) - S e^{-r \tau} M\Phi\left( \frac{- \ln(M) + (r - \sigma^2/2)\tau}{\sigma\sqrt{\tau}} \right) \, $$

# %% [markdown]
# ### Python Imports

# %%
# Distribution functions
from scipy.stats import norm

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import BatchNormalization
from keras.wrappers.scikit_learn import KerasClassifier
from keras.callbacks import EarlyStopping

# Load libraries
import numpy as np
import pandas as pd
import pandas_datareader.data as web
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import seaborn as sns

from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# Error Metrics
from sklearn.metrics import mean_squared_error

# Feature Selection
from sklearn.feature_selection import SelectKBest
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import chi2, f_regression

#Plotting 
from pandas.plotting import scatter_matrix

# Random Seed
np.random.seed(13)

# %%
#Diable the warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Defining functions and parameters

# %% [markdown]
# ### True Parameters

# %% [markdown]
# ### Vol and Option Pricing Functions

# %%
def call_option_price(s0, M, t, v):
    
    d1=(-np.log(M)+(r+np.square(v)/2)*t)/(v*np.sqrt(t))
    d2=(-np.log(M)+(r-np.square(v)/2)*t)/(v*np.sqrt(t))
    N_d1 = norm.cdf(d1)
    N_d2 = norm.cdf(d2)
    return s0 * N_d1 - s0 * M * np.exp(-r*t) * N_d2

# %% [markdown]
# ## Start Coursework Here

# %% [markdown]
# Generate option prices for a range of K, T, sigma holding r fixed

# %%
r = 0.02
s0 = 100.0
N = 10000

# %%
Ms = np.array((0.5+1.0*np.random.random(N)))
Vs = np.array(np.random.uniform(0.1, 0.5, N)) # add more randomness to the volatility
Vs2 =  Vs.copy()
Ts = np.array(np.random.random(N)) * 5.0
Ts2 =  Ts.copy()

Ps = np.array([call_option_price(100/m, m, t, v) for m, t, v in zip(Ms,Ts,Vs)])

# %%
Ps.mean()
# Out:
# 30.652598310140526

# %%
Y = Ps.copy()
X = np.concatenate([Ms.reshape(-1,1), Ts.reshape(-1,1),Vs.reshape(-1,1)],axis=1)

dataset = pd.DataFrame(np.concatenate([Y.reshape(-1,1), X], axis=1),
                       columns=['Price', 'Moneyness', 'Time', 'Volatility'])

# %%
dataset
# Out:
#           Price  Moneyness      Time  Volatility
# 0      3.735972   1.277702  1.789969    0.224770
# 1     39.675734   0.737541  1.231403    0.242953
# 2      3.653933   1.324279  4.027271    0.147598
# 3      0.806695   1.465749  1.784467    0.189859
# 4      0.549242   1.472601  1.667874    0.181977
# ...         ...        ...       ...         ...
# 9995   5.195986   1.296672  0.701826    0.456636
# 9996   1.048266   1.073503  0.457678    0.122301
# 9997  63.447906   0.632526  1.044442    0.411851
# 9998   4.481944   1.298178  0.587229    0.468628
# 9999  40.757011   0.799070  3.764479    0.248958
#
# [10000 rows x 4 columns]

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option('display.precision', 3)
dataset.describe()
# Out:
#           Price  Moneyness      Time  Volatility
# count 10000.000  10000.000 10000.000   10000.000
# mean     30.653      1.004     2.500       0.300
# std      28.202      0.289     1.446       0.116
# min       0.000      0.500     0.000       0.100
# 25%       7.971      0.750     1.241       0.199
# 50%      21.738      1.008     2.488       0.301
# 75%      46.626      1.254     3.760       0.400
# max     125.336      1.500     5.000       0.500

# %%
plt.plot(Ms, Vs);
plt.xlabel("Moneyness (K/S)")
plt.ylabel("Volatility");

# %% [markdown]
# ### 3.2. Data Visualization

# %%
dataset.hist(bins=50, sharex=False, sharey=False, xlabelsize=10, ylabelsize=10, figsize=(15,12));

# %% [markdown]
# We can see that the price has an interesting distribution with a spike at $0$ due to all of the OTM options. Strike is Gaussian distributed around 100 and the time is uniformally distributed out to 5 years

# %% [markdown]
# Next we look at the interaction between different variables

# %%
X.shape[1:]
# Out:
# (3,)

# %%
Y.shape
# Out:
# (10000,)

# %% [markdown]
# We see some very interesting non linear analysis. This means that we expect our non linear models to do a better job than our linear models.

# %% [markdown]
# ### 3.3 Feature Importance Analysis

# %%
bestfeatures = SelectKBest(k='all', score_func=f_regression)
fit = bestfeatures.fit(X,Y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(['Strike', 'Time', 'Volatility'])
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
featureScores.nlargest(10,'Score').set_index('Specs')  #print 10 best features
# Out:
#                Score
# Specs
# Strike     33258.007
# Time         425.897
# Volatility   303.830

# %% [markdown]
# ## 4. Evaluating Models and Parameters

# %% [markdown]
# ### 4.1. Train Test Split

# %%
dataset
# Out:
#       Price  Moneyness  Time  Volatility
# 0     3.736      1.278 1.790       0.225
# 1    39.676      0.738 1.231       0.243
# 2     3.654      1.324 4.027       0.148
# 3     0.807      1.466 1.784       0.190
# 4     0.549      1.473 1.668       0.182
# ...     ...        ...   ...         ...
# 9995  5.196      1.297 0.702       0.457
# 9996  1.048      1.074 0.458       0.122
# 9997 63.448      0.633 1.044       0.412
# 9998  4.482      1.298 0.587       0.469
# 9999 40.757      0.799 3.764       0.249
#
# [10000 rows x 4 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset.iloc[:,1:], 
                                                              dataset.iloc[:,0],
                                                              random_state=42)

# %%
y_test
# Out:
# 6252   32.806
# 4684   34.602
# 1731    4.511
# 4742   40.746
# 4521    1.433
#         ...
# 4862   29.491
# 7025   51.354
# 7647   76.421
# 7161   92.235
# 73     20.608
# Name: Price, Length: 2500, dtype: float64

# %%
X_test.applymap('{:,.6f}'.format)
# Out:
#      Moneyness      Time Volatility
# 6252  1.164093  4.586722   0.489577
# 4684  0.950294  4.648455   0.326453
# 1731  1.476376  3.682006   0.223627
# 4742  0.744891  0.696709   0.456017
# 4521  1.448923  2.488680   0.178372
# ...        ...       ...        ...
# 4862  0.966597  4.599176   0.278848
# 7025  0.695171  3.136357   0.176345
# 7647  0.589599  1.435388   0.410615
# 7161  0.567470  2.429784   0.489693
# 73    0.864916  2.038090   0.111280
#
# [2500 rows x 3 columns]

# %%
call_option_price(100, 0.864916, 2.038090, 0.111280)
# Out:
# 17.824534550839928

# %%
X_train.shape
# Out:
# (7500, 3)

# %%
#scaler = StandardScaler()
#X = scaler.fit_transform(X)
#X_test = scaler.transform(X_test)
#X_train = scaler.transform(X_train)

# %%
r = 0.02
s0 = 100.0

def option_vol(m):
    a = 0.35
    b = -0.1
    c = 0.02
    vol = a + b*m + c*m*m
    return vol

moneyness = np.linspace(0.5, 2.0, 100)
v = option_vol(moneyness)

N = 10000

Ms_ = (0.5+1.0*np.random.random(N))
Ts_ = np.random.random(N) * 5.0
Vs_ = option_vol(Ms)
Ps_ = np.array([call_option_price(s0, m, t, v) for m, t, v in zip(Ms_,Ts_,Vs_)])

Y_ = Ps

X_ = np.concatenate([Ms.reshape(-1,1), Ts.reshape(-1,1), Vs.reshape(-1,1)], axis=1)

dataset = pd.DataFrame(np.concatenate([Y.reshape(-1,1), X], axis=1),
                       columns=['Price', 'Moneyness', 'Time', 'Volatility'])

validation_size = 0.2

train_size = int(len(X_) * (1-validation_size))
X_train_, X_test_ = X_[0:train_size], X_[train_size:len(X_)]
Y_train_, Y_test_ = Y_[0:train_size], Y_[train_size:len(X_)]

scoring = 'neg_mean_squared_error' 

from sklearn.neural_network import MLPRegressor

model = MLPRegressor()

# %%
res = model.fit(X_train, y_train)
train_result = mean_squared_error(res.predict(X_train), y_train)
train_result
# Out:
# 16.520165091002927

# %%
test_result = mean_squared_error(res.predict(X_test), y_test)
test_result
# Out:
# 17.65461905798252

# %%
predictions = res.predict(X)
mean_squared_error(Y, predictions)
# Out:
# 16.803778582747828

# %%
X
# Out:
# array([[1.27770241, 1.78996949, 0.2247701 ],
#        [0.73754122, 1.2314032 , 0.24295272],
#        [1.32427853, 4.0272711 , 0.14759849],
#        ...,
#        [0.63252624, 1.04444241, 0.4118506 ],
#        [1.29817773, 0.58722879, 0.46862846],
#        [0.79906977, 3.76447894, 0.2489582 ]])

# %%
X_test
# Out:
#       Moneyness  Time  Volatility
# 6252      1.164 4.587       0.490
# 4684      0.950 4.648       0.326
# 1731      1.476 3.682       0.224
# 4742      0.745 0.697       0.456
# 4521      1.449 2.489       0.178
# ...         ...   ...         ...
# 4862      0.967 4.599       0.279
# 7025      0.695 3.136       0.176
# 7647      0.590 1.435       0.411
# 7161      0.567 2.430       0.490
# 73        0.865 2.038       0.111
#
# [2500 rows x 3 columns]

# %%
s0 = 100.0
strike = np.linspace(0.7*s0, 1.3*s0, 100)
moneyness = strike / s0
time_to_maturity = np.ones(100)*1
option_vol_vector = option_vol(moneyness)

np.array([moneyness, time_to_maturity, option_vol_vector]).transpose()
# Out:
# array([[0.7       , 1.        , 0.2898    ],
#        [0.70606061, 1.        , 0.28936437],
#        [0.71212121, 1.        , 0.28893021],
#        [0.71818182, 1.        , 0.28849752],
#        [0.72424242, 1.        , 0.2880663 ],
#        [0.73030303, 1.        , 0.28763655],
#        [0.73636364, 1.        , 0.28720826],
#        [0.74242424, 1.        , 0.28678145],
#        [0.74848485, 1.        , 0.28635611],
#        [0.75454545, 1.        , 0.28593223],
#        [0.76060606, 1.        , 0.28550983],
#        [0.76666667, 1.        , 0.28508889],
#        [0.77272727, 1.        , 0.28466942],
#        [0.77878788, 1.        , 0.28425142],
#        [0.78484848, 1.        , 0.28383489],
#        [0.79090909, 1.        , 0.28341983],
#        [0.7969697 , 1.        , 0.28300624],
#        [0.8030303 , 1.        , 0.28259412],
#        [0.80909091, 1.        , 0.28218347],
#        [0.81515152, 1.        , 0.28177429],
#        [0.82121212, 1.        , 0.28136657],
#        [0.82727273, 1.        , 0.28096033],
#        [0.83333333, 1.        , 0.28055556],
#        [0.83939394, 1.        , 0.28015225],
#        [0.84545455, 1.        , 0.27975041],
#        [0.85151515, 1.        , 0.27935005],
#        [0.85757576, 1.        , 0.27895115],
#        [0.86363636, 1.        , 0.27855372],
#        [0.86969697, 1.        , 0.27815776],
#        [0.87575758, 1.        , 0.27776327],
#        [0.88181818, 1.        , 0.27737025],
#        [0.88787879, 1.        , 0.2769787 ],
#        [0.89393939, 1.        , 0.27658861],
#        [0.9       , 1.        , 0.2762    ],
#        [0.90606061, 1.        , 0.27581286],
#        [0.91212121, 1.        , 0.27542718],
#        [0.91818182, 1.        , 0.27504298],
#        [0.92424242, 1.        , 0.27466024],
#        [0.93030303, 1.        , 0.27427897],
#        [0.93636364, 1.        , 0.27389917],
#        [0.94242424, 1.        , 0.27352084],
#        [0.94848485, 1.        , 0.27314399],
#        [0.95454545, 1.        , 0.2727686 ],
#        [0.96060606, 1.        , 0.27239467],
#        [0.96666667, 1.        , 0.27202222],
#        [0.97272727, 1.        , 0.27165124],
#        [0.97878788, 1.        , 0.27128173],
#        [0.98484848, 1.        , 0.27091368],
#        [0.99090909, 1.        , 0.27054711],
#        [0.9969697 , 1.        , 0.270182  ],
#        [1.0030303 , 1.        , 0.26981837],
#        [1.00909091, 1.        , 0.2694562 ],
#        [1.01515152, 1.        , 0.2690955 ],
#        [1.02121212, 1.        , 0.26873627],
#        [1.02727273, 1.        , 0.26837851],
#        [1.03333333, 1.        , 0.26802222],
#        [1.03939394, 1.        , 0.2676674 ],
#        [1.04545455, 1.        , 0.26731405],
#        [1.05151515, 1.        , 0.26696217],
#        [1.05757576, 1.        , 0.26661175],
#        [1.06363636, 1.        , 0.26626281],
#        [1.06969697, 1.        , 0.26591534],
#        [1.07575758, 1.        , 0.26556933],
#        [1.08181818, 1.        , 0.26522479],
#        [1.08787879, 1.        , 0.26488173],
#        [1.09393939, 1.        , 0.26454013],
#        [1.1       , 1.        , 0.2642    ],
#        [1.10606061, 1.        , 0.26386134],
#        [1.11212121, 1.        , 0.26352415],
#        [1.11818182, 1.        , 0.26318843],
#        [1.12424242, 1.        , 0.26285418],
#        [1.13030303, 1.        , 0.2625214 ],
#        [1.13636364, 1.        , 0.26219008],
#        [1.14242424, 1.        , 0.26186024],
#        [1.14848485, 1.        , 0.26153186],
#        [1.15454545, 1.        , 0.26120496],
#        [1.16060606, 1.        , 0.26087952],
#        [1.16666667, 1.        , 0.26055556],
#        [1.17272727, 1.        , 0.26023306],
#        [1.17878788, 1.        , 0.25991203],
#        [1.18484848, 1.        , 0.25959247],
#        [1.19090909, 1.        , 0.25927438],
#        [1.1969697 , 1.        , 0.25895776],
#        [1.2030303 , 1.        , 0.25864261],
#        [1.20909091, 1.        , 0.25832893],
#        [1.21515152, 1.        , 0.25801671],
#        [1.22121212, 1.        , 0.25770597],
#        [1.22727273, 1.        , 0.25739669],
#        [1.23333333, 1.        , 0.25708889],
#        [1.23939394, 1.        , 0.25678255],
#        [1.24545455, 1.        , 0.25647769],
#        [1.25151515, 1.        , 0.25617429],
#        [1.25757576, 1.        , 0.25587236],
#        [1.26363636, 1.        , 0.2555719 ],
#        [1.26969697, 1.        , 0.25527291],
#        [1.27575758, 1.        , 0.25497539],
#        [1.28181818, 1.        , 0.25467934],
#        [1.28787879, 1.        , 0.25438476],
#        [1.29393939, 1.        , 0.25409164],
#        [1.3       , 1.        , 0.2538    ]])

# %%
def plot_fit(tmat):

    s0 = 100.0
    strike = np.linspace(0.7*s0, 1.3*s0, 100)
    moneyness = strike / s0
    time_to_maturity = np.ones(100)*tmat
    option_vol_vector = option_vol(moneyness)

    bs_price = call_option_price(100/moneyness, moneyness, time_to_maturity, option_vol_vector)

    X_ = np.array([moneyness, time_to_maturity, option_vol_vector]).transpose()
    #X_ = scaler.transform(X_)
    predicted_price = res.predict(X_)

    plt.plot(strike, bs_price, label='Black Scholes')
    plt.plot(strike, predicted_price, label='Predicted Price')
    plt.xlabel("Strike")
    plt.ylabel("Call Option Value")
    plt.title("Expiry in " + str(tmat) + " yea")
    plt.legend();

# %%
plot_fit(1.00)

# %%
def plot_fit(tmat):

    s0 = 100.0
    strike = np.linspace(0.7*s0, 1.3*s0, 100)
    moneyness = strike / s0
    time_to_maturity = np.ones(100)*tmat
    option_vol_vector = option_vol(moneyness)

    bs_price = call_option_price(100/moneyness, moneyness, time_to_maturity, option_vol_vector)

    X_ = np.array([moneyness, time_to_maturity, option_vol_vector]).transpose()
    #X_ = scaler.transform(X_)
    predicted_price = res.predict(X_)

    plt.plot(strike, bs_price, label='Black Scholes')
    plt.plot(strike, predicted_price, label='Predicted Price')
    plt.xlabel("Strike")
    plt.ylabel("Call Option Value")
    plt.title("Expiry in " + str(tmat) + " yea")
    plt.legend();

# %%
plot_fit(0.50)

# %% [markdown]
# ### 4.2. Setting up a Neural Network model using Keras

# %% [markdown]
# We setup the first NN with the following attributes:
#
# * 3 input layers - one for each feature
# * 3 hidden layers with 50 nodes each and relu activation
# * One output layer with linear activation for linear regression
# * 40 epochs
# * Minimium Squared Error as loss function
# * ADAM as default optimizer

# %%
# Setting up a training function
learning_rate=0.001
optimizer = tf.keras.optimizers.Adam(learning_rate)

def train_model(hidden_layers, nodes, optimizer=optimizer):
    model = Sequential()
    
    
    model.add(Input(shape=X_train.shape[1:]))

    for x in range(0, hidden_layers):
        model.add(Dense(nodes, activation='relu'))
        #model.add(Dropout(0.20))
    
    model.add(Dense(1))

    model.compile(loss='mean_squared_error', optimizer = optimizer)
    
    return model

# %%
# Model summary
train_model(hidden_layers=1, nodes=100).summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               400
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 501
# Trainable params: 501
# Non-trainable params: 0
# _________________________________________________________________

# %%
len(X_train)
# Out:
# 7500

# %%
# Fitting the model using earlystopping

g = train_model(hidden_layers=3, nodes=50).fit(X_train, y_train, epochs=100, batch_size=200, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 38/38 [==============================] - 1s 6ms/step - loss: 1659.0416 - val_loss: 1513.6663
# Epoch 2/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1187.8495 - val_loss: 851.2909
# Epoch 3/100
# 38/38 [==============================] - 0s 2ms/step - loss: 848.5327 - val_loss: 808.1728
# Epoch 4/100
# 38/38 [==============================] - 0s 3ms/step - loss: 800.0374 - val_loss: 754.2072
# Epoch 5/100
# 38/38 [==============================] - 0s 3ms/step - loss: 737.0941 - val_loss: 677.1066
# Epoch 6/100
# 38/38 [==============================] - ETA: 0s - loss: 662.667 - 0s 3ms/step - loss: 639.2166 - val_loss: 554.7384
# Epoch 7/100
# 38/38 [==============================] - 0s 3ms/step - loss: 474.8521 - val_loss: 351.0475
# Epoch 8/100
# 38/38 [==============================] - 0s 3ms/step - loss: 245.5394 - val_loss: 151.7521
# Epoch 9/100
# 38/38 [==============================] - 0s 3ms/step - loss: 113.2325 - val_loss: 91.8670
# Epoch 10/100
# 38/38 [==============================] - 0s 3ms/step - loss: 74.7346 - val_loss: 63.9190
# Epoch 11/100
# 38/38 [==============================] - 0s 4ms/step - loss: 53.5054 - val_loss: 47.0654
# Epoch 12/100
# 38/38 [==============================] - 0s 3ms/step - loss: 39.8345 - val_loss: 36.0549
# Epoch 13/100
# 38/38 [==============================] - 0s 4ms/step - loss: 31.9510 - val_loss: 29.8168
# Epoch 14/100
# 38/38 [==============================] - 0s 3ms/step - loss: 25.6972 - val_loss: 23.6229
# Epoch 15/100
# 38/38 [==============================] - 0s 3ms/step - loss: 21.4314 - val_loss: 19.9524
# Epoch 16/100
# 38/38 [==============================] - 0s 3ms/step - loss: 18.2905 - val_loss: 17.3000
# Epoch 17/100
# 38/38 [==============================] - 0s 3ms/step - loss: 16.1242 - val_loss: 15.2508
# Epoch 18/100
# 38/38 [==============================] - 0s 3ms/step - loss: 14.4121 - val_loss: 13.5462
# Epoch 19/100
# 38/38 [==============================] - 0s 3ms/step - loss: 13.0843 - val_loss: 12.3186
# Epoch 20/100
# 38/38 [==============================] - 0s 3ms/step - loss: 12.1149 - val_loss: 11.1910
# Epoch 21/100
# 38/38 [==============================] - 0s 4ms/step - loss: 10.7724 - val_loss: 10.1726
# Epoch 22/100
# 38/38 [==============================] - 0s 4ms/step - loss: 9.8807 - val_loss: 9.4101
# Epoch 23/100
# 38/38 [==============================] - 0s 3ms/step - loss: 9.0145 - val_loss: 8.5554
# Epoch 24/100
# 38/38 [==============================] - 0s 3ms/step - loss: 8.3767 - val_loss: 7.7742
# Epoch 25/100
# 38/38 [==============================] - 0s 3ms/step - loss: 7.6304 - val_loss: 7.2978
# Epoch 26/100
# 38/38 [==============================] - 0s 3ms/step - loss: 6
100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.2521 - val_loss: 0.2976
# Epoch 97/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.2690 - val_loss: 0.2727
# Epoch 98/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.2543 - val_loss: 0.2930
# Epoch 99/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.2643 - val_loss: 0.3197
# Epoch 100/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.2410 - val_loss: 0.2509

# %%
final_loss_adam = g.history['loss'][-1]
final_val_loss_adam = g.history['val_loss'][-1]

# %%
final_val_loss_adam
# Out:
# 0.2509315609931946

# %% [markdown]
# ### 4.3. Evaluating Results

# %% [markdown]
# First, we look at the Loss x Epochs graphic to analyse the efficiency gain in our model

# %%
plt.plot(g.history['loss'], label='loss')
plt.plot(g.history['val_loss'], label='val_loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend();

# %% [markdown]
# Now, we create a Predicted x Actual price graph to have a visual on how well is our model predicting the label

# %%
g.model.predict(X)
# Out:
# array([[ 3.4357677],
#        [40.26271  ],
#        [ 3.861867 ],
#        ...,
#        [63.17221  ],
#        [ 3.976984 ],
#        [40.548836 ]], dtype=float32)

# %%
g.model(X)
predicted_price = g.model.predict(X)

# %%
Y
# Out:
# array([ 3.73597178, 39.67573362,  3.65393315, ..., 63.44790646,
#         4.48194425, 40.75701146])

# %%
X
# Out:
# array([[1.27770241, 1.78996949, 0.2247701 ],
#        [0.73754122, 1.2314032 , 0.24295272],
#        [1.32427853, 4.0272711 , 0.14759849],
#        ...,
#        [0.63252624, 1.04444241, 0.4118506 ],
#        [1.29817773, 0.58722879, 0.46862846],
#        [0.79906977, 3.76447894, 0.2489582 ]])

# %%
call_option_price(100, 1.27770241, 1.78996949, 0.2247701)
# Out:
# 4.773460358673336

# %%
plt.plot(Ms, Y, label='Black Scholes')
plt.plot(Ms, predicted_price, label='Predicted Price')
plt.xlabel("Strike")
plt.ylabel("Call Option Value")
plt.title("Expiry in " + str(0.5) + " yea")
plt.legend()

# %%
predictions = g.model.predict(X)
plt.figure(figsize = (15,10))
plt.scatter(Y, predictions)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.axline((15,15), (18, 18), linewidth=2, color='r')
plt.grid(True)

# %%
final_val_loss_adam
# Out:
# 0.2509315609931946

# %% [markdown]
# ### 4.4. Choosing best optimizer

# %% [markdown]
# Now, before moving on to the analysis of the neural network structure, let's see if we can get better results using Rmsprop instead of Adam

# %%
g_2 = train_model(hidden_layers=3, nodes=50, optimizer='rmsprop').fit(X_train, y_train, epochs=100, batch_size=200,validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 38/38 [==============================] - 1s 5ms/step - loss: 1537.6451 - val_loss: 1258.8903
# Epoch 2/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1019.7205 - val_loss: 858.4569
# Epoch 3/100
# 38/38 [==============================] - 0s 3ms/step - loss: 856.3973 - val_loss: 821.3741
# Epoch 4/100
# 38/38 [==============================] - 0s 2ms/step - loss: 822.1097 - val_loss: 787.7963
# Epoch 5/100
# 38/38 [==============================] - 0s 3ms/step - loss: 784.4225 - val_loss: 744.4490
# Epoch 6/100
# 38/38 [==============================] - 0s 3ms/step - loss: 735.8860 - val_loss: 691.0876
# Epoch 7/100
# 38/38 [==============================] - 0s 3ms/step - loss: 664.5560 - val_loss: 600.8781
# Epoch 8/100
# 38/38 [==============================] - 0s 3ms/step - loss: 548.7160 - val_loss: 461.2226
# Epoch 9/100
# 38/38 [==============================] - 0s 3ms/step - loss: 381.7674 - val_loss: 283.1729
# Epoch 10/100
# 38/38 [==============================] - 0s 3ms/step - loss: 220.9278 - val_loss: 166.7467
# Epoch 11/100
# 38/38 [==============================] - 0s 3ms/step - loss: 132.1912 - val_loss: 111.5021
# Epoch 12/100
# 38/38 [==============================] - 0s 3ms/step - loss: 93.6051 - val_loss: 81.1782
# Epoch 13/100
# 38/38 [==============================] - 0s 3ms/step - loss: 70.7044 - val_loss: 72.4426
# Epoch 14/100
# 38/38 [==============================] - 0s 4ms/step - loss: 56.4373 - val_loss: 52.5774
# Epoch 15/100
# 38/38 [==============================] - 0s 3ms/step - loss:
# Epoch 58/100
# 38/38 [==============================] - 0s 3ms/step - loss: 7.2750 - val_loss: 7.7140
# Epoch 59/100
# 38/38 [==============================] - 0s 3ms/step - loss: 7.2797 - val_loss: 7.9019
# Epoch 60/100
# 38/38 [==============================] - 0s 3ms/step - loss: 7.2189 - val_loss: 8.3908
# Epoch 61/100
# 38/38 [==============================] - 0s 4ms/step - loss: 6.6932 - val_loss: 4.0242
# Epoch 62/100
# 38/38 [==============================] - 0s 3ms/step - loss: 6.4416 - val_loss: 4.9337
# Epoch 63/100
# 38/38 [==============================] - 0s 3ms/step - loss: 7.1692 - val_loss: 3.9096
# Epoch 64/100
# 38/38 [==============================] - 0s 4ms/step - loss: 6.4297 - val_loss: 8.6000
# Epoch 65/100
# 38/38 [==============================] - 0s 2ms/step - loss: 6.5138 - val_loss: 9.3490
# Epoch 66/100
# 38/38 [==============================] - 0s 3ms/step - loss: 6.3703 - val_loss: 7.7635
# Epoch 67/100
# 38/38 [==============================] - 0s 3ms/step - loss: 6.2474 - val_loss: 4.2595
# Epoch 68/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.8223 - val_loss: 8.4434
# Epoch 69/100
# 38/38 [==============================] - 0s 3ms/step - loss: 6.8814 - val_loss: 3.5845
# Epoch 70/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.8031 - val_loss: 3.3946
# Epoch 71/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.8218 - val_loss: 8.3290
# Epoch 72/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2492 - val_loss: 5.2472
# Epoch 73/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.8883 - val_loss: 6.0273
# Epoch 74/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3787 - val_loss: 5.8179
# Epoch 75/100
# 38/38 [==============================] - 0s 3ms/step - loss: 6.2791 - val_loss: 2.7816
# Epoch 76/100
# 38/38 [==============================] - 0s 3ms/step - loss: 4.9165 - val_loss: 2.8972
# Epoch 77/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.1515 - val_loss: 4.2775
# Epoch 78/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.0866 - val_loss: 5.9794
# Epoch 79/100
# 38/38 [==============================] - 0s 3ms/step - loss: 4.9074 - val_loss: 4.8062
# Epoch 80/100
# 38/38 [==============================] - 0s 4ms/step - loss: 4.9651 - val_loss: 2.3634
# Epoch 81/100
# 38/38 [==============================] - 0s 3ms/step - loss: 4.4221 - val_loss: 5.9928
# Epoch 82/100
# 38/38 [==============================] - 0s 3ms/step - loss: 4.8876 - val_loss: 1.9109
# Epoch 83/100
# 38/38 [==============================] - 0s 3ms/step - loss: 3.9610 - val_loss: 7.2824
# Epoch 84/100
# 38/38 [==============================] - 0s 3ms/step - loss: 4.6590 - val_loss: 2.4343
# Epoch 85/100
# 38/38 [==============================] - 0s 3ms/step - loss: 3.5066 - val_loss: 3.7413
# Epoch 86/100
# 38/38 [==============================] - 0s 3ms/step - loss: 4.3170 - val_loss: 2.9559
# Epoch 87/100
# 38/38 [==============================] - 0s 3ms/step - loss: 4.3203 - val_loss: 9.0772
# Epoch 88/100
# 38/38 [==============================] - 0s 3ms/step - loss: 4.0388 - val_loss: 4.6027
# Epoch 89/100
# 38/38 [==============================] - 0s 3ms/step - loss: 3.9642 - val_loss: 4.9284
# Epoch 90/100
# 38/38 [==============================] - 0s 3ms/step - loss: 3.7683 - val_loss: 8.9755
# Epoch 91/100
# 38/38 [==============================] - 0s 3ms/step - loss: 4.3244 - val_loss: 1.2553
# Epoch 92/100
# 38/38 [==============================] - 0s 3ms/step - loss: 3.5384 - val_loss: 1.9152
# Epoch 93/100
# 38/38 [==============================] - 0s 3ms/step - loss: 3.8454 - val_loss: 2.8288
# Epoch 94/100
# 38/38 [==============================] - 0s 3ms/step - loss: 3.9596 - val_loss: 4.3094
# Epoch 95/100
# 38/38 [==============================] - 0s 3ms/step - loss: 3.7809 - val_loss: 1.3028
# Epoch 96/100
# 38/38 [==============================] - 0s 3ms/step - loss: 3.6809 - val_loss: 2.6201
# Epoch 97/100
# 38/38 [==============================] - 0s 4ms/step - loss: 3.7014 - val_loss: 4.9898
# Epoch 98/100
# 38/38 [==============================] - 0s 3ms/step - loss: 3.5186 - val_loss: 2.0170
# Epoch 99/100
# 38/38 [==============================] - 0s 3ms/step - loss: 3.5927 - val_loss: 3.7577
# Epoch 100/100
# 38/38 [==============================] - 0s 3ms/step - loss: 3.4760 - val_loss: 3.4268

# %%
final_loss_rms = g_2.history['loss'][-1]
final_val_loss_rms = g_2.history['val_loss'][-1]

# %%
predictions_2 = g_2.model.predict(X_test)
plt.figure(figsize = (15,10))
plt.scatter(y_test, predictions_2)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.axline((16,16), (18, 18), linewidth=2, color='r')
plt.grid(True)

# %%
opt_compare = pd.DataFrame(data=[[final_val_loss_adam, final_val_loss_rms]], columns = ['Adam', 'RmsProp'])
opt_compare
# Out:
#    Adam  RmsProp
# 0 0.251    3.427

# %% [markdown]
# We can observe that the final loss using Adam is slightly better, and the Prediction x Actual graph using Adam also looks better, so we will stick to that optimizer from now on

# %% [markdown]
# ### 4.5. Analysing Neural Network structure

# %% [markdown]
# To better understand and find the most adequate Neural Network structure for this model, we will retrain it with varying values for hidden layers and number of neurons per layer. We'll be using the following parameters:
#
# * Inputs:
#     * Hidden layers: array [1,2,3,4]
#     * Neurons: [10,20,50,100]
#
#
# * Outputs:
#     * 16 different NN models, containing:
#         * Final loss
#         * Final val loss

# %% [markdown]
# First, we loop through the inputs and store the results in a dataframe:

# %%
results_df = pd.DataFrame(columns=['Hidden layers', 'Nodes', 'Val Loss'])

for i in [1, 2, 3, 4]:
    for x in [10, 20, 50, 100]:
        nn = train_model(hidden_layers=i, nodes = x, optimizer=optimizer).fit(X_train, y_train, epochs=100, batch_size = 200, verbose=1, validation_data=(X_test, y_test))
        L = [i, x, nn.history['val_loss'][-1]]
        results_df.loc[len(results_df)] = L
# Out:
# Epoch 1/100
# 38/38 [==============================] - 1s 5ms/step - loss: 1664.1903 - val_loss: 1526.5688
# Epoch 2/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1404.2291 - val_loss: 1276.0555
# Epoch 3/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1180.7114 - val_loss: 1083.7281
# Epoch 4/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1022.6425 - val_loss: 956.6049
# Epoch 5/100
# 38/38 [==============================] - 0s 2ms/step - loss: 925.8910 - val_loss: 883.8159
# Epoch 6/100
# 38/38 [==============================] - 0s 3ms/step - loss: 872.8511 - val_loss: 844.2687
# Epoch 7/100
# 38/38 [==============================] - 0s 3ms/step - loss: 843.9825 - val_loss: 820.2986
# Epoch 8/100
# 38/38 [==============================] - 0s 3ms/step - loss: 824.8549 - val_loss: 802.9994
# Epoch 9/100
# 38/38 [==============================] - 0s 2ms/step - loss: 809.7950 - val_loss: 786.0409
# Epoch 10/100
# 38/38 [==============================] - 0s 3ms/step - loss: 792.8109 - val_loss: 769.7107
# Epoch 11/100
# 38/38 [==============================] - 0s 2ms/step - loss: 777.2310 - val_loss: 753.9417
# Epoch 12/100
# 38/38 [==============================] - 0s 2ms/step - loss: 762.0174 - val_loss: 738.8414
# Epoch 13/100
# 38/38 [==============================] - 0s 3ms/step - loss: 747.1368 - val_loss: 723.9150
# Epoch 14/100
# 38/38 [==============================] - 0s 3ms/step - loss: 732.3996 - val_loss: 709.1571
# Epoch 15/100
# 38/38 [==============================] - 0s 3ms/step - loss: 717.9210 - val_loss: 695.0436
# Epoch 16/100
# 38/38 [==============================] - 0s 3ms/step - loss: 703.4836 - val_loss: 680.5249
# Epoch 17/100
# 38/38 [==============================] - 0s 3ms/step - loss: 689.1583 - val_loss: 666.0073
# Epoch 18/100
# 38/38 [==============================] - 0s 2ms/step - loss: 674.9142 - val_loss: 652.0852
# Epoch 19/100
# 38/38 [==============================] - 0s 2ms/step - loss: 660.7449 - val_loss: 638.3010
# Epoch 20/100
# 38/38 [==============================] - 0s 2ms/step - loss: 646.7100 - val_loss: 624.1129
# Epoch 21/100
# 38/38 [==============================] - 0s 3ms/step - loss: 632.5764 - val_loss: 610.3102
# Epoch 22/100
# 38/38 [==============================] - 0s 3ms/step - loss: 618.5945 - val_loss: 596.5868
# Epoch 23/100
# 38/38 [==============================] - 0s 3ms/step - loss: 604.5149 - val_loss: 582.6937
# Epoch 24/100
# 38/38 [==============================] - 0s 3ms/step - loss: 590.6135 - val_loss: 568.8400
# Epoch 25/100
# 38/38 [==============================] - 0s 3ms/step - loss: 576.9589 - val_loss: 555.3041
# Epoch 26/100
# 38/38 [==============================] - 0s 3ms/step - loss: 562.9763 - val_loss: 542.1675
# Epoch 27/100
# 38/38 [==============================] - 0s 3ms/step - loss: 549.3997 - val_loss: 528.6317
# Epoch 28/100
# 38/38 [==============================] - 0s 3ms/step - loss: 535.8679 - val_loss: 515.4080
# Epoch 29/100
# 38/38 [==============================] - 0s 3ms/step - loss: 522.4575 - val_loss: 502.3870
# Epoch 30/100
# 38/38 [==============================] - 0s 3ms/step - loss: 509.2468 - val_loss: 489.4969
# Epoch 31/100
# 38/38 [==============================] - 0s 3ms/step - loss: 496.1325 - val_loss: 476.7488
# Epoch 32/100
# 38/38 [==============================] - 0s 2ms/step - loss: 483.1146 - val_loss: 463.9464
# Epoch 33/100
# 38/38 [==============================] - 0s 4ms/step - loss: 470.2545 - val_loss: 451.6933
# Epoch 34/100
# 38/38 [==============================] - 0s 3ms/step - loss: 457.5594 - val_loss: 439.5001
# Epoch 35/100
# 38/38 [==============================] - 0s 2ms/step - loss: 445.0707 - val_loss: 427.2019
# Epoch 36/100
# 38/38 [==============================] - 0s 2ms/step - loss: 432.7005 - val_loss: 415.3209
# Epoch 37/100
# 38/38 [==============================] - 0s 2ms/step - loss: 420.6401 - val_loss: 403.7322
# Epoch 38/100
# 38/38 [==============================] - 0s 3ms/step - loss: 408.7751 - val_loss: 392.3284
# Epoch 39/100
# 38/38 [==============================] - 0s 3ms/step - loss: 397.1178 - val_loss: 381.2788
# Epoch 40/100
# 38/38 [==============================] - 0s 2ms/step - loss: 385.7195 - val_loss: 370.2326
# Epoch 41/100
# 38/38 [==============================] - 0s 2ms/step - loss: 374.5057 - val_loss: 359.5427
# Epoch 42/100
# 38/38 [==============================] - 0s 3ms/step - loss: 363.6288 - val_loss: 349.1155
# Epoch 43/100
# 38/38 [==============================] - 0s 3ms/step - loss: 353.0538 - val_loss: 338.9188
# Epoch 44/100
# 38/38 [==============================] - 0s 2ms/step - loss: 342.5807 - val_loss: 329.0925
# Epoch 45/100
# 38/38 [==============================] - 0s 3ms/step - loss: 332.4820 - val_loss: 319.3525
# Epoch 46/100
# 38/38 [==============================] - 0s 3ms/step - loss:
# Epoch 94/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0350 - val_loss: 0.0653
# Epoch 95/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0593 - val_loss: 0.0387
# Epoch 96/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0735 - val_loss: 0.1131
# Epoch 97/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1415 - val_loss: 0.0575
# Epoch 98/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0410 - val_loss: 0.0440
# Epoch 99/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0479 - val_loss: 0.0435
# Epoch 100/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0440 - val_loss: 0.0352

# %%
results_df
# Out:
#     Hidden layers   Nodes  Val Loss
# 0           1.000  10.000   115.657
# 1           1.000  20.000    92.259
# 2           1.000  50.000    48.576
# 3           1.000 100.000    23.496
# 4           2.000  10.000     5.675
# 5           2.000  20.000     1.724
# 6           2.000  50.000     2.487
# 7           2.000 100.000     0.225
# 8           3.000  10.000     3.564
# 9           3.000  20.000     2.963
# 10          3.000  50.000     0.278
# 11          3.000 100.000     0.043
# 12          4.000  10.000     3.829
# 13          4.000  20.000     0.290
# 14          4.000  50.000     0.235
# 15          4.000 100.000     0.035

# %% [markdown]
# Now we find the architechture with the least Loss value

# %%
best_arch = results_df.sort_values('Val Loss').iloc[0]
best_arch
# Out:
# Hidden layers     4.000
# Nodes           100.000
# Val Loss          0.035
# Name: 15, dtype: float64

# %% [markdown]
# Let's take a look at the Predicted x Actual Graph with this new architechture

# %%
nn = train_model(hidden_layers=4, nodes = 100, optimizer=optimizer).fit(X_train, y_train, epochs=100, batch_size = 200, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 38/38 [==============================] - 1s 6ms/step - loss: 932.4478 - val_loss: 594.1846
# Epoch 2/100
# 38/38 [==============================] - 0s 2ms/step - loss: 250.6155 - val_loss: 63.8455
# Epoch 3/100
# 38/38 [==============================] - 0s 3ms/step - loss: 35.5288 - val_loss: 17.8142
# Epoch 4/100
# 38/38 [==============================] - 0s 4ms/step - loss: 13.7497 - val_loss: 10.0713
# Epoch 5/100
# 38/38 [==============================] - 0s 4ms/step - loss: 8.7310 - val_loss: 6.7307
# Epoch 6/100
# 38/38 [==============================] - 0s 4ms/step - loss: 6.0520 - val_loss: 4.7621
# Epoch 7/100
# 38/38 [==============================] - 0s 4ms/step - loss: 4.2848 - val_loss: 3.2249
# Epoch 8/100
# 38/38 [==============================] - 0s 4ms/step - loss: 2.5765 - val_loss: 1.6514
# Epoch 9/100
# 38/38 [==============================] - 0s 5ms/step - loss: 1.1580 - val_loss: 0.7971
# Epoch 10/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6712 - val_loss: 0.5774
# Epoch 11/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5658 - val_loss: 0.5713
# Epoch 12/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4459 - val_loss: 0.5380
# Epoch 13/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.3775 - val_loss: 0.3607
# Epoch 14/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.3230 - val_loss: 0.3609
# Epoch 15/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.2944 - val_loss: 0.2648
# Epoch 16/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.3129 - val_loss: 0.3639
# Epoch 17/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.2865 - val_loss: 0.2329
# Epoch 18/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.2056 - val_loss: 0.1939
# Epoch 19/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.2124 - val_loss: 0.1869
# Epoch 20/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1777 - val_loss: 0.1956
# Epoch 21/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1713 - val_loss: 0.1726
# Epoch 22/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1666 - val_loss: 0.1808
# Epoch 23/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1494 - val_loss: 0.1548
# Epoch 24/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1473 - val_loss: 0.1624
# Epoch 25/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1435 - val_loss: 0.1427
# Epoch 26/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1485 - val_loss: 0.1335
# Epoch 27/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1302 - val_loss: 0.1275
# Epoch 28/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1309 - val_loss: 0.1424
# Epoch 29/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1266 - val_loss: 0.1347
# Epoch 30/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1187 - val_loss: 0.1260
# Epoch 31/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1493 - val_loss: 0.1413
# Epoch 32/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1599 - val_loss: 0.1925
# Epoch 33/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1266 - val_loss: 0.1271
# Epoch 34/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1136 - val_loss: 0.1398
# Epoch 35/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1000 - val_loss: 0.1101
# Epoch 36/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1113 - val_loss: 0.1210
# Epoch 37/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1013 - val_loss: 0.1105
# Epoch 38/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0960 - val_loss: 0.1120
# Epoch 39/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0954 - val_loss: 0.1011
# Epoch 40/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0906 - val_loss: 0.1081
# Epoch 41/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0955 - val_loss: 0.1463
# Epoch 42/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1024 - val_loss: 0.0932
# Epoch 43/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0923 - val_loss: 0.1013
# Epoch 44/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0999 - val_loss: 0.1674
# Epoch 45/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1091 - val_loss: 0.1056
# Epoch 46/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1122 - val_loss: 0.2032
# Epoch 47/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0944 - val_loss: 0.1082
# Epoch 48/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0862 - val_loss: 0.0912
# Epoch 49/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0887 - val_loss: 0.0983
# Epoch 50/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0995 - val_loss: 0.1607
# Epoch 51/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1016 - val_loss: 0.0990
# Epoch 52/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0935 - val_loss: 0.1145
# Epoch 53/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1001 - val_loss: 0.1126
# Epoch 54/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0928 - val_loss: 0.0962
# Epoch 55/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0739 - val_loss: 0.0987
# Epoch 56/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0832 - val_loss: 0.1315
# Epoch 57/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1161 - val_loss: 0.0898
# Epoch 58/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0849 - val_loss: 0.0908
# Epoch 59/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0889 - val_loss: 0.0825
# Epoch 60/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0712 - val_loss: 0.2018
# Epoch 61/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0832 - val_loss: 0.0776
# Epoch 62/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0662 - val_loss: 0.0851
# Epoch 63/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0659 - val_loss: 0.0728
# Epoch 64/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0625 - val_loss: 0.0895
# Epoch 65/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0606 - val_loss: 0.0773
# Epoch 66/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0668 - val_loss: 0.0717
# Epoch 67/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0657 - val_loss: 0.0720
# Epoch 68/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0665 - val_loss: 0.1153
# Epoch 69/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0854 - val_loss: 0.1130
# Epoch 70/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1141 - val_loss: 0.1962
# Epoch 71/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1469 - val_loss: 0.0758
# Epoch 72/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0793 - val_loss: 0.1019
# Epoch 73/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0585 - val_loss: 0.0914
# Epoch 74/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0657 - val_loss: 0.0710
# Epoch 75/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0680 - val_loss: 0.1106
# Epoch 76/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0871 - val_loss: 0.0655
# Epoch 77/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0568 - val_loss: 0.0765
# Epoch 78/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0762 - val_loss: 0.0704
# Epoch 79/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0895 - val_loss: 0.0999
# Epoch 80/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0635 - val_loss: 0.0651
# Epoch 81/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1139 - val_loss: 0.0618
# Epoch 82/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0546 - val_loss: 0.1095
# Epoch 83/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0628 - val_loss: 0.2325
# Epoch 84/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1222 - val_loss: 0.0582
# Epoch 85/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0548 - val_loss: 0.0682
# Epoch 86/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0519 - val_loss: 0.0900
# Epoch 87/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0556 - val_loss: 0.0563
# Epoch 88/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0520 - val_loss: 0.0589
# Epoch 89/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0601 - val_loss: 0.0615
# Epoch 90/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0942 - val_loss: 0.0605
# Epoch 91/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0712 - val_loss: 0.0627
# Epoch 92/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0670 - val_loss: 0.0579
# Epoch 93/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1004 - val_loss: 0.0559
# Epoch 94/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0649 - val_loss: 0.0554
# Epoch 95/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1930 - val_loss: 1.3887
# Epoch 96/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.3602 - val_loss: 0.1875
# Epoch 97/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1387 - val_loss: 0.0877
# Epoch 98/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0853 - val_loss: 0.0618
# Epoch 99/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0575 - val_loss: 0.1105
# Epoch 100/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0508 - val_loss: 0.0985

# %%
predictions_2 = nn.model.predict(X_test)
plt.figure(figsize = (15,10))
plt.scatter(y_test, predictions_2)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.axline((0,0), (17.5, 17.5), linewidth=2, color='r')
plt.grid(True)

# %% [markdown]
# ## 5. Calculating and Analysing delta

# %% [markdown]
# For this part of the question, we will firt calculate Delta using the Black-Scholes equation in the training and test examples.
#
# $$\Delta C=\mathrm{e}^{-qt}N(d1)$$

# %% [markdown]
# $$  Se^{-q \tau}\Phi(d_1) - e^{-r \tau} K\Phi(d_2) \, $$

# %% [markdown]
# With

# %% [markdown]
# $$  d_1 = \frac{\ln(S/K) + (r - q + \sigma^2/2)\tau}{\sigma\sqrt{\tau}}  $$

# %% [markdown]
# and

# %% [markdown]
# $$  d_2 = \frac{\ln(S/K) + (r - q - \sigma^2/2)\tau}{\sigma\sqrt{\tau}} = d_1 - \sigma\sqrt{\tau}  $$

# %% [markdown]
# Where we have;
#     Stock price $S$;
#     Strike price $K$;
#     Risk-free rate $r$;
#     Annual dividend yield $q$;
#     Time to maturity $\tau = T-t$ (represented as a unit-less fraction of one year);
#     Volatility $\sigma$

# %% [markdown]
# In order to make the logic simpler, we define *Moneyness* as $M = K/S$ and look at the prices in terms of per unit of current stock price. We also set $q$ as $0$

# %% [markdown]
# This simplifes the formula down to the following

# %% [markdown]
# $$  S e^{-q \tau}\Phi\left( \frac{- \ln(M) + (r+ \sigma^2/2 )\tau}{\sigma\sqrt{\tau}}\right) - S e^{-r \tau} M\Phi\left( \frac{- \ln(M) + (r - \sigma^2/2)\tau}{\sigma\sqrt{\tau}} \right) \, $$

# %%
# Defining the call_delta function
def call_delta(M, t, v, q):
    # Black Scholes Equation
    d1=(-np.log(M)+(r+np.square(v)/2)*t)/(v*np.sqrt(t))
    N_d1 = norm.cdf(d1)
    return np.exp(-q*t) * N_d1

# %%
# Testing the new function
call_delta(0.79906977, 3.76447894, 0.2489582, 0)
# Out:
# 0.805588857405409

# %%
delta_BS = np.array([call_delta(M, t, v, 0) for M, t, v in zip(Ms,Ts,Vs)])

# %%
delta_BS
# Out:
# array([0.2926984 , 0.9123468 , 0.29867905, ..., 0.91121853, 0.30347908,
#        0.80558886])

# %%
len(delta_BS.reshape(-1,1))
# Out:
# 10000

# %% [markdown]
# -----------------------------------------++++++-----------------------------------
#
# Now, we will calculate Delta using our trained network. To do this, we will calculate the new call price P' considering a 0.01 variation in stock price, which is equivalent to a 0.0001 variation in moneyness (S0=100, Strike=100). With that value we are able to calculate Delta by applying:
#
# $$\Delta C=(P'-P) / 0.01$$

# %%
pd.set_option('display.float_format', lambda x: '%.8f' % x)

# %%
# Creating new dataset with new share price (+0.01 variation)
# obs: The price variation is effectively calculated in the new Moneyness value (Ms2)

dataset_new = pd.DataFrame(dataset, columns=['Moneyness','Time','Volatility'])
Ms2=1/((((1/Ms)*100)+0.01)/100)
X_new = np.concatenate([Ms2.reshape(-1,1), Ts2.reshape(-1,1),Vs2.reshape(-1,1)],axis=1)
#X_new = scaler.transform(X_new)
Ps2 = np.array([call_option_price(100/m, m, t, v) for m, t, v in zip(Ms2,Ts2,Vs2)])
dataset_new = pd.DataFrame(data=np.concatenate((Ps2.reshape(-1,1),X_new),axis=1), columns=['Price,','Moneyness','Time','Volatility'])
X_train_new, X_test_new, y_train_new, y_test_new = train_test_split(dataset_new.iloc[:,1:], 
                                                              dataset_new.iloc[:,0],
                                                              random_state=42)

# %%
# yhat_1_IS = In sample predicted values before price variation
# yhat_1_OS = Out of sample predicted values before price vatiation

# yhat_2_IS = In sample predicted values after price variation
# yhat_2_OS = Out of sample predicted values after price variation


yhat_1_IS = nn.model.predict(X_train)
yhat_1_OS = nn.model.predict(X_test)

yhat_2_IS = nn.model.predict(X_train_new)
yhat_2_OS = nn.model.predict(X_test_new)

# %%
plt.figure(figsize = (15,10))
plt.scatter(yhat_2_IS, y_train_new)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.axline((0,0), (17.5, 17.5), linewidth=2, color='r')
plt.grid(True)

# %%
yhat_2_IS
# Out:
# array([[52.073757 ],
#        [ 9.103634 ],
#        [17.38857  ],
#        ...,
#        [72.9716   ],
#        [ 6.4761415],
#        [24.587633 ]], dtype=float32)

# %%
y_train.max()
# Out:
# 121.650507016881

# %%
y_train_new.max()
# Out:
# 121.65951316461567

# %%
yhat_1_IS
# Out:
# array([[52.06471 ],
#        [ 9.099312],
#        [17.381592],
#        ...,
#        [72.96171 ],
#        [ 6.47213 ],
#        [24.581236]], dtype=float32)

# %%
delta_1_IS = (yhat_2_IS - yhat_1_IS) / 0.01
delta_1_OS = (yhat_2_OS - yhat_1_OS) / 0.01

delta_2_IS = (np.array(y_train_new) - np.array(y_train)) / 0.01
delta_2_OS = (np.array(y_test_new) - np.array(y_test)) / 0.01

# %%
np.array(y_train_new)
# Out:
# array([52.91458163,  9.22452453, 17.47294862, ..., 73.54063733,
#         6.40377733, 24.82489698])

# %%
np.array(y_train)
# Out:
# array([52.90615083,  9.22031279, 17.46629806, ..., 73.53063777,
#         6.39914624, 24.81863857])

# %%
delta_1_IS
# Out:
# array([[0.9048462 ],
#        [0.4322052 ],
#        [0.69789886],
#        ...,
#        [0.9895325 ],
#        [0.4011631 ],
#        [0.63972473]], dtype=float32)

# %%
# defining the DataFrame with BS prices

Ms_d_OS=dataset.iloc[y_test.index,:]['Moneyness']
Ts_d_OS=dataset.iloc[y_test.index,:]['Time']
Vs_d_OS=dataset.iloc[y_test.index,:]['Volatility']

delta_BS_OS = np.array([call_delta(M, t, v, 0) for M, t, v in zip(Ms_d_OS,Ts_d_OS,Vs_d_OS)])

Ms_d_IS=dataset.iloc[y_train.index,:]['Moneyness']
Ts_d_IS=dataset.iloc[y_train.index,:]['Time']
Vs_d_IS=dataset.iloc[y_train.index,:]['Volatility']

delta_BS_IS = np.array([call_delta(M, t, v, 0) for M, t, v in zip(Ms_d_IS,Ts_d_IS,Vs_d_IS)])


# After price shock
Ms_n_IS = X_train_new['Moneyness']
Ms_n_OS = X_test_new['Moneyness']

# %%
Ms_d_IS.values
# Out:
# array([0.7081972 , 1.43206496, 0.92876655, ..., 0.5841479 , 1.16083249,
#        1.13083051])

# %%
comparison = pd.DataFrame(data=yhat_2_IS.reshape(-1,1), columns=['yhat_2_IS'])
comparison['yhat_1_IS'] = pd.DataFrame(yhat_1_IS.reshape(-1,1))
comparison['delta_1_IS'] = pd.DataFrame(delta_1_IS.reshape(-1,1))
comparison['y_2_IS'] = pd.DataFrame(np.array(y_train_new).reshape(-1,1))
comparison['y_1_IS'] = pd.DataFrame(np.array(y_train).reshape(-1,1))
comparison['delta_2_IS'] = pd.DataFrame(delta_2_IS.reshape(-1,1))
comparison['delta_BS_IS'] = pd.DataFrame(delta_BS_IS.reshape(-1,1))
comparison['Ms_2_IS'] = pd.DataFrame(Ms_n_IS.values)
comparison['Ms_1_IS'] = pd.DataFrame(Ms_d_IS.values)
comparison['Ts_IS'] = pd.DataFrame(Ts_d_IS.values)
comparison['Vs_IS'] = pd.DataFrame(Vs_d_IS.values)
comparison[11] = comparison['yhat_2_IS'] -comparison['y_2_IS']
comparison[12] = comparison['yhat_1_IS'] -comparison['y_1_IS']
comparison[13] = comparison['delta_1_IS'] -comparison['delta_2_IS']

comparison
# Out:
#        yhat_2_IS   yhat_1_IS  delta_1_IS      y_2_IS      y_1_IS  delta_2_IS  \
# 0    52.07375717 52.06470871  0.90484619 52.91458163 52.90615083  0.84307986
# 1     9.10363388  9.09931183  0.43220520  9.22452453  9.22031279  0.42117372
# 2    17.38857079 17.38159180  0.69789886 17.47294862 17.46629806  0.66505595
# 3     8.22390270  8.21936607  0.45366287  8.31630830  8.31189513  0.44131726
# 4    30.86226845 30.85514832  0.71201324 31.13988744 31.13321543  0.66720128
# ...          ...         ...         ...         ...         ...         ...
# 7495 11.31029892 11.30566502  0.46339035 11.31465796 11.31002692  0.46310345
# 7496 80.07599640 80.06640625  0.95901489 80.13647227 80.12669890  0.97733703
# 7497 72.97160339 72.96170807  0.98953247 73.54063733 73.53063777  0.99995524
# 7498  6.47614145  6.47212982  0.40116310  6.40377733  6.39914624  0.46310911
# 7499 24.58763313 24.58123589  0.63972473 24.82489698 24.81863857  0.62584025
#
#       delta_BS_IS    Ms_2_IS    Ms_1_IS      Ts_IS      Vs_IS          11  \
# 0      0.84306333 0.70814705 0.70819720 2.03754739 0.36039826 -0.84082446
# 1      0.42112563 1.43185991 1.43206496 3.68322522 0.30343195 -0.12089065
# 2      0.66500113 0.92868030 0.92876655 0.49987984 0.43650531 -0.08437784
# 3      0.44125437 1.26205288 1.26221218 4.79748835 0.18078181 -0.09240560
# 4      0.66718003 1.15592380 1.15605743 4.17830112 0.48363632 -0.27761900
# ...           ...        ...        ...        ...        ...         ...
# 7495   0.46305802 1.33175381 1.33193119 3.15649556 0.32772211 -0.00435904
# 7496   0.97733233 0.56216839 0.56220000 0.86254891 0.34702743 -0.06047587
# 7497   0.99995521 0.58411378 0.58414790 1.18434219 0.13416604 -0.56903393
# 7498   0.46301345 1.16069776 1.16083249 4.88605846 0.10902813  0.07236413
# 7499   0.62581211 1.13070265 1.13083051 3.86834540 0.38708221 -0.23726384
#
#               12          13
# 0    -0.84144212  0.06176633
# 1    -0.12100096  0.01103148
# 2    -0.08470627  0.03284292
# 3    -0.09252906  0.01234561
# 4    -0.27806712  0.04481197
# ...          ...         ...
# 7495 -0.00436191  0.00028690
# 7496 -0.06029265 -0.01832213
# 7497 -0.56892971 -0.01042277
# 7498  0.07298359 -0.06194601
# 7499 -0.23740269  0.01388448
#
# [7500 rows x 14 columns]

# %%
comparison2 = pd.DataFrame(data=yhat_2_OS.reshape(-1,1), columns=['yhat_2_OS'])
comparison2['yhat_1_OS'] = pd.DataFrame(yhat_1_OS.reshape(-1,1))
comparison2['delta_1_OS'] = pd.DataFrame(delta_1_OS.reshape(-1,1))
comparison2['y_2_OS'] = pd.DataFrame(np.array(y_test_new).reshape(-1,1))
comparison2['y_1_OS'] = pd.DataFrame(np.array(y_test).reshape(-1,1))
comparison2['delta_2_OS'] = pd.DataFrame(delta_2_OS.reshape(-1,1))
comparison2['delta_BS_OS'] = pd.DataFrame(delta_BS_OS.reshape(-1,1))
comparison2['Ms_2_OS'] = pd.DataFrame(Ms_n_OS.values)
comparison2['Ms_1_OS'] = pd.DataFrame(Ms_d_OS.values)
comparison2['Ts_OS'] = pd.DataFrame(Ts_d_OS.values)
comparison2['Vs_OS'] = pd.DataFrame(Vs_d_OS.values)
comparison2[11] = comparison2['yhat_2_OS'] -comparison2['y_2_OS']
comparison2[12] = comparison2['yhat_1_OS'] -comparison2['y_1_OS']
comparison2[13] = comparison2['delta_1_OS'] -comparison2['delta_2_OS']

comparison2
# Out:
#        yhat_2_OS   yhat_1_OS  delta_1_OS      y_2_OS      y_1_OS  delta_2_OS  \
# 0    32.48051834 32.47330856  0.72097778 32.81323272 32.80643562  0.67970987
# 1    34.39770126 34.39090347  0.67977905 34.60879576 34.60168506  0.71106987
# 2     4.47696543  4.47422552  0.27399063  4.51450859  4.51149874  0.30098440
# 3    40.46872330 40.45988846  0.88348389 40.75405341 40.74563808  0.84153326
# 4     1.37694764  1.37558794  0.13597012  1.43433882  1.43275220  0.15866165
# ...          ...         ...         ...         ...         ...         ...
# 2495 29.35465813 29.34717178  0.74863434 29.49840635 29.49145761  0.69487378
# 2496 51.60525513 51.59639359  0.88615417 51.36332976 51.35397061  0.93591535
# 2497 75.67701721 75.66844940  0.85678101 76.42983671 76.42067725  0.91594605
# 2498 91.96224213 91.95404816  0.81939697 92.24375248 92.23492744  0.88250475
# 2499 20.27910805 20.26926994  0.98381042 20.61734891 20.60840581  0.89431055
#
#       delta_BS_OS    Ms_2_OS    Ms_1_OS      Ts_OS      Vs_OS          11  \
# 0      0.67969001 1.16395779 1.16409329 4.58672245 0.48957707 -0.33271438
# 1      0.71104680 0.95020382 0.95029412 4.64845508 0.32645325 -0.21109450
# 2      0.30092450 1.47615843 1.47637636 3.68200552 0.22362679 -0.03754316
# 3      0.84150960 0.74483520 0.74489068 0.69670903 0.45601728 -0.28533011
# 4      0.15859936 1.44871354 1.44892345 2.48867955 0.17837199 -0.05739117
# ...           ...        ...        ...        ...        ...         ...
# 2495   0.69484546 0.96650342 0.96659685 4.59917621 0.27884824 -0.14374823
# 2496   0.93590139 0.69512294 0.69517126 3.13635659 0.17634510  0.24192537
# 2497   0.91593680 0.58956390 0.58959866 1.43538792 0.41061522 -0.75281950
# 2498   0.88249743 0.56743759 0.56746979 2.42978440 0.48969270 -0.28151036
# 2499   0.89426081 0.86484116 0.86491596 2.03809033 0.11128002 -0.33824087
#
#               12          13
# 0    -0.33312706  0.04126791
# 1    -0.21078159 -0.03129082
# 2    -0.03727322 -0.02699377
# 3    -0.28574962  0.04195063
# 4    -0.05716426 -0.02269153
# ...          ...         ...
# 2495 -0.14428583  0.05376056
# 2496  0.24242298 -0.04976117
# 2497 -0.75222784 -0.05916504
# 2498 -0.28087928 -0.06310778
# 2499 -0.33913587  0.08949987
#
# [2500 rows x 14 columns]

# %%
new_comp = comparison2.sort_values(by=['delta_BS_OS'], ascending=False).copy()
new_comp
# Out:
#        yhat_2_OS   yhat_1_OS  delta_1_OS      y_2_OS      y_1_OS  delta_2_OS  \
# 1319 95.00452423 94.99536896  0.91552734 95.64618862 95.63618862  1.00000000
# 954  64.57405090 64.56446075  0.95901489 65.14240425 65.13240425  1.00000000
# 2254 87.22472382 87.21465302  1.00708008 87.00141583 86.99141583  1.00000000
# 1813 97.70180511 97.69318390  0.86212158 99.39428999 99.38428999  1.00000000
# 5    81.54743195 81.53784180  0.95901489 82.00535366 81.99535366  1.00000000
# ...          ...         ...         ...         ...         ...         ...
# 884  -0.08145800 -0.08157593  0.01179278  0.00000000  0.00000000  0.00000000
# 77   -0.08161569 -0.08175173  0.01360476  0.00000000  0.00000000  0.00000000
# 651  -0.13951296 -0.13955513  0.00421703  0.00000000  0.00000000  0.00000000
# 2076 -0.12753227 -0.12755167  0.00194013  0.00000000  0.00000000  0.00000000
# 512  -0.10689311 -0.10698220  0.00890940  0.00000000  0.00000000  0.00000000
#
#       delta_BS_OS    Ms_2_OS    Ms_1_OS      Ts_OS      Vs_OS          11  \
# 1319   1.00000000 0.51218166 0.51220790 0.20188865 0.14129415 -0.64166439
# 954    1.00000000 0.60593127 0.60596798 0.05362059 0.17927379 -0.56835334
# 2254   1.00000000 0.53713798 0.53716683 0.41648564 0.11161323  0.22330799
# 1813   1.00000000 0.50161118 0.50163634 0.01834968 0.16609325 -1.69248488
# 5      1.00000000 0.54990214 0.54993239 0.07746860 0.13068154 -0.45792172
# ...           ...        ...        ...        ...        ...         ...
# 884    0.00000000 1.37676230 1.37695187 0.16036029 0.12171224 -0.08145800
# 77     0.00000000 1.40039343 1.40058957 0.20507396 0.10693466 -0.08161569
# 651    0.00000000 1.49064221 1.49086445 0.15600873 0.13894750 -0.13951296
# 2076   0.00000000 1.48625456 1.48647549 0.06255136 0.17920498 -0.12753227
# 512    0.00000000 1.38074743 1.38093810 0.01723320 0.17435430 -0.10689311
#
#               12          13
# 1319 -0.64081966 -0.08447266
# 954  -0.56794349 -0.04098511
# 2254  0.22323718  0.00708008
# 1813 -1.69110609 -0.13787842
# 5    -0.45751187 -0.04098511
# ...          ...         ...
# 884  -0.08157593  0.01179278
# 77   -0.08175173  0.01360476
# 651  -0.13955513  0.00421703
# 2076 -0.12755167  0.00194013
# 512  -0.10698220  0.00890940
#
# [2500 rows x 14 columns]

# %%
call_delta(new_comp.iloc[0,8], new_comp.iloc[0,9], new_comp.iloc[0,10], 0)
# Out:
# 1.0

# %%
aaa =call_option_price(100, new_comp.iloc[0,8], new_comp.iloc[0,9], new_comp.iloc[0,10])

# %%
bbb = call_option_price(100.01, new_comp.iloc[0,7], new_comp.iloc[0,9], new_comp.iloc[0,10])

# %%
aaa - bbb
# Out:
# -0.007511685855966732

# %%
1/new_comp.iloc[0,8]-1/new_comp.iloc[0,7]
# Out:
# -9.99999999995449e-05

# %%
Ms_d=dataset.iloc[y_test.index,:]['Moneyness']
Ts_d=dataset.iloc[y_test.index,:]['Time']
Vs_d=dataset.iloc[y_test.index,:]['Volatility']

delta_BS = np.array([call_delta(M, t, v, 0) for M, t, v in zip(Ms_d,Ts_d,Vs_d)])
plt.figure(figsize = (15,10))
plt.scatter(delta_BS,delta_1_OS)
plt.xlabel("Actual Delta")
plt.ylabel("Predicted Delta")
plt.axline((0,0), (1, 1), linewidth=2, color='r')
plt.grid(True)
plt.title('NN Delta approx x BS Delta')
# Out:
# Text(0.5, 1.0, 'NN Delta approx x BS Delta')

# %%
Ms_d=dataset.iloc[y_test.index,:]['Moneyness']
Ts_d=dataset.iloc[y_test.index,:]['Time']
Vs_d=dataset.iloc[y_test.index,:]['Volatility']

delta_BS = np.array([call_delta(M, t, v, 0) for M, t, v in zip(Ms_d,Ts_d,Vs_d)])
plt.figure(figsize = (15,10))
plt.scatter(delta_BS,delta_2_OS)
plt.xlabel("Actual Delta")
plt.ylabel("Predicted Delta")
plt.axline((0,0), (1, 1), linewidth=2, color='r')
plt.grid(True)
plt.title('Actual Delta approx x BS Delta')
# Out:
# Text(0.5, 1.0, 'Actual Delta approx x BS Delta')

# %%
Ts.min()
# Out:
# 0.0001860207120341073

# %%
dataset.iloc[y_test.index,:]
# Out:
#            Price  Moneyness       Time  Volatility
# 6252 32.80643562 1.16409329 4.58672245  0.48957707
# 4684 34.60168506 0.95029412 4.64845508  0.32645325
# 1731  4.51149874 1.47637636 3.68200552  0.22362679
# 4742 40.74563808 0.74489068 0.69670903  0.45601728
# 4521  1.43275220 1.44892345 2.48867955  0.17837199
# ...          ...        ...        ...         ...
# 4862 29.49145761 0.96659685 4.59917621  0.27884824
# 7025 51.35397061 0.69517126 3.13635659  0.17634510
# 7647 76.42067725 0.58959866 1.43538792  0.41061522
# 7161 92.23492744 0.56746979 2.42978440  0.48969270
# 73   20.60840581 0.86491596 2.03809033  0.11128002
#
# [2500 rows x 4 columns]

# %%
np.sort(y_test.index)
# Out:
# array([   0,    3,    8, ..., 9989, 9993, 9998], dtype=int64)

# %%
delta_1_IS
# Out:
# array([[0.9048462 ],
#        [0.4322052 ],
#        [0.69789886],
#        ...,
#        [0.9895325 ],
#        [0.4011631 ],
#        [0.63972473]], dtype=float32)

# %%
delta_2_OS
# Out:
# array([0.67970987, 0.71106987, 0.3009844 , ..., 0.91594605, 0.88250475,
#        0.89431055])

# %%
delta_1_OS
# Out:
# array([[0.7209778 ],
#        [0.67977905],
#        [0.27399063],
#        ...,
#        [0.856781  ],
#        [0.819397  ],
#        [0.9838104 ]], dtype=float32)

# %%
predictions_2
# Out:
# array([[32.47331  ],
#        [34.390903 ],
#        [ 4.4742255],
#        ...,
#        [75.66845  ],
#        [91.95405  ],
#        [20.26927  ]], dtype=float32)

# %%
yhat_1_OS
# Out:
# array([[32.47331  ],
#        [34.390903 ],
#        [ 4.4742255],
#        ...,
#        [75.66845  ],
#        [91.95405  ],
#        [20.26927  ]], dtype=float32)

# %%
yhat_2_OS
# Out:
# array([[32.48052  ],
#        [34.3977   ],
#        [ 4.4769654],
#        ...,
#        [75.67702  ],
#        [91.96224  ],
#        [20.279108 ]], dtype=float32)

# %%
y_train
# Out:
# 4901   52.90615083
# 4375    9.22031279
# 6698   17.46629806
# 9805    8.31189513
# 1101   31.13321543
#            ...
# 5734   11.31002692
# 5191   80.12669890
# 5390   73.53063777
# 860     6.39914624
# 7270   24.81863857
# Name: Price, Length: 7500, dtype: float64

# %%
y_train_new
# Out:
# 4901   52.91458163
# 4375    9.22452453
# 6698   17.47294862
# 9805    8.31630830
# 1101   31.13988744
#            ...
# 5734   11.31465796
# 5191   80.13647227
# 5390   73.54063733
# 860     6.40377733
# 7270   24.82489698
# Name: Price,, Length: 7500, dtype: float64

# %%
Ms2=1/((1/Ms)+0.0001)
Ps2 = np.array([call_option_price(100.01, m, t, v) for m, t, v in zip(Ms2,Ts2,Vs2)])

# %%
# We start by replicating the full sample X, altering just the moneyness
#Vs2 = np.array([dataset['Volatility']]).copy()
#Ts2 = np.array([dataset['Time']]).copy()
#Ms2 = np.array([dataset['Moneyness']]).copy() # We add 0.0001 to the moneyness column (equivalent to adding 0.01 to price)

X2 = np.concatenate([Ms2.reshape(-1,1), Ts2.reshape(-1,1), Vs2.reshape(-1,1)], axis=1)

# %%
X2
# Out:
# array([[1.27753918, 1.78996949, 0.2247701 ],
#        [0.73748683, 1.2314032 , 0.24295272],
#        [1.32410318, 4.0272711 , 0.14759849],
#        ...,
#        [0.63248623, 1.04444241, 0.4118506 ],
#        [1.29800923, 0.58722879, 0.46862846],
#        [0.79900592, 3.76447894, 0.2489582 ]])

# %%
X
# Out:
# array([[1.27770241, 1.78996949, 0.2247701 ],
#        [0.73754122, 1.2314032 , 0.24295272],
#        [1.32427853, 4.0272711 , 0.14759849],
#        ...,
#        [0.63252624, 1.04444241, 0.4118506 ],
#        [1.29817773, 0.58722879, 0.46862846],
#        [0.79906977, 3.76447894, 0.2489582 ]])

# %%
# Now we define the predicted Call Prices before and after the stock price alteration using our previously defined model
pred_prices = nn.model.predict(X)
pred_prices_2 = nn.model.predict(X2)

# %%
pred_prices_2
# Out:
# array([[ 3.599194 ],
#        [39.600285 ],
#        [ 3.4802685],
#        ...,
#        [63.33104  ],
#        [ 4.435209 ],
#        [40.525677 ]], dtype=float32)

# %%
pred_prices
# Out:
# array([[ 3.5963907],
#        [39.591457 ],
#        [ 3.4772   ],
#        ...,
#        [63.321987 ],
#        [ 4.4323587],
#        [40.51749  ]], dtype=float32)

# %%
Ps
# Out:
# array([ 3.73597178, 39.67573362,  3.65393315, ..., 63.44790646,
#         4.48194425, 40.75701146])

# %%
Ps2
# Out:
# array([ 4.77706825, 29.26998622,  4.84262458, ..., 40.13970424,
#         5.82212716, 32.57478749])

# %%
delta_NN = (pred_prices_2-Y)/0.01
delta_NN
# Out:
# array([[-1.36777731e+01, -3.60765396e+03, -5.47390987e+00, ...,
#         -5.98487124e+03, -8.82750205e+01, -3.71578174e+03],
#        [ 3.58643128e+03, -7.54490470e+00,  3.59463514e+03, ...,
#         -2.38476219e+03,  3.51183403e+03, -1.15672688e+02],
#        [-2.55703302e+01, -3.61954651e+03, -1.73664670e+01, ...,
#         -5.99676380e+03, -1.00167578e+02, -3.72767430e+03],
#        ...,
#        [ 5.95950676e+03,  2.36553058e+03,  5.96771063e+03, ...,
#         -1.16867033e+01,  5.88490952e+03,  2.25740280e+03],
#        [ 6.99237017e+01, -3.52405248e+03,  7.81275649e+01, ...,
#         -5.90126977e+03, -4.67354574e+00, -3.63218027e+03],
#        [ 3.67897049e+03,  8.49943104e+01,  3.68717436e+03, ...,
#         -2.29222297e+03,  3.60437325e+03, -2.31334734e+01]])

# %%
plt.figure(figsize = (15,10))
plt.scatter(Ps2, pred_prices_2)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.axline((0,0), (17.5, 17.5), linewidth=2, color='r')
plt.grid(True)

# %%
plt.figure(figsize = (15,10))
plt.scatter(delta_BS, delta_NN)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.axline((0,0), (1, 1), linewidth=2, color='r')
plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-271999b3a423> in <module>
#       1 plt.figure(figsize = (15,10))
# ----> 2 plt.scatter(delta_BS, delta_NN)
#       3 plt.xlabel("Actual Price")
#       4 plt.ylabel("Predicted Price")
#       5 plt.axline((0,0), (1, 1), linewidth=2, color='r')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2888         verts=cbook.deprecation._deprecated_parameter,
#    2889         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2890     __ret = gca().scatter(
#    2891         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2892         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4439         y = np.ma.ravel(y)
#    4440         if x.size != y.size:
# -> 4441             raise ValueError("x and y must be the same size")
#    4442
#    4443         if s is None:
#
# ValueError: x and y must be the same size

# %%
delta_NN2= (Ps2-Ps)/0.01
delta_NN2

# %%
pd.DataFrame(delta_NN2).plot()

# %%
pd.DataFrame(delta_NN).plot()

# %%
delta_BS

# %%
delta_NN

# %%
Ps

# %%
Ps2

# %%
call_option_price(100,0.92437493, 2.31493874, 0.20886596)

# %%
call_option_price(100.01,0.92428949, 2.31493874, 0.20886596)

# %%
call_delta(0.92437493,2.31493874,0.20886596,0)

# %%
(18.66008297379434-18.65338255618996)/0.01

# %%
X

# %%
X2

# %% [markdown]
# ### Looking at testing error x moneyness

# %%
nn.history['val_loss']

# %% [markdown]
# # Include learning rate in adam and rmsprop

# %% [markdown]
# # Do standarization of features
