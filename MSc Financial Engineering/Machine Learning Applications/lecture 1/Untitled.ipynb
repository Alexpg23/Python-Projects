# %%
# !pip install pandas_datareader
# Out:
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# Requirement already satisfied: requests>=2.19.0 in c:\users\apala\anaconda3\lib\site-packages (from pandas_datareader) (2.25.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\apala\anaconda3\lib\site-packages (from pandas_datareader) (1.2.4)
# Requirement already satisfied: lxml in c:\users\apala\anaconda3\lib\site-packages (from pandas_datareader) (4.6.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\apala\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\apala\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\apala\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.20.1)
# Requirement already satisfied: six>=1.5 in c:\users\apala\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas_datareader) (1.15.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\apala\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\apala\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\apala\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\apala\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (1.26.4)
# Installing collected packages: pandas-datareader
# Successfully installed pandas-datareader-0.10.0

# %%
# !pip install pandas-datareader
# Out:
# Requirement already satisfied: pandas-datareader in c:\users\apala\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: lxml in c:\users\apala\anaconda3\lib\site-packages (from pandas-datareader) (4.6.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\apala\anaconda3\lib\site-packages (from pandas-datareader) (2.25.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\apala\anaconda3\lib\site-packages (from pandas-datareader) (1.2.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\apala\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\apala\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (1.20.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\apala\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\apala\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas-datareader) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\apala\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\apala\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\apala\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\apala\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2021.10.8)

# %%
import pandas_datareader.data as web

# %%
from datetime import datetime

start='2014'
end = datetime(2021, 12, 15)

fb_data = web.DataReader('FB', 'yahoo', start=start, end=end)
fb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2004 entries, 2014-01-02 to 2021-12-15
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       2004 non-null   float64
#  1   Low        2004 non-null   float64
#  2   Open       2004 non-null   float64
#  3   Close      2004 non-null   float64
#  4   Volume     2004 non-null   int64
#  5   Adj Close  2004 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 109.6 KB

# %%
import os
import pandas as pd
from pprint import pprint

# %%
fb_data
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2014-01-02   55.220001   54.189999   54.830002   54.709999  43195500
# 2014-01-03   55.650002   54.529999   55.020000   54.560001  38246200
# 2014-01-06   57.259998   54.049999   54.419998   57.200001  68852600
# 2014-01-07   58.549999   57.220001   57.700001   57.919998  77207400
# 2014-01-08   58.410000   57.230000   57.599998   58.230000  56682400
# ...                ...         ...         ...         ...       ...
# 2021-12-09  336.130005  328.000000  329.540009  329.820007  16879200
# 2021-12-10  335.029999  326.369995  332.559998  329.750000  14520900
# 2021-12-13  341.089996  329.589996  330.950012  334.489990  22948700
# 2021-12-14  335.700012  327.649994  328.049988  333.739990  20461000
# 2021-12-15  342.109985  323.980011  332.489990  341.660004  24681300
#
#              Adj Close
# Date
# 2014-01-02   54.709999
# 2014-01-03   54.560001
# 2014-01-06   57.200001
# 2014-01-07   57.919998
# 2014-01-08   58.230000
# ...                ...
# 2021-12-09  329.820007
# 2021-12-10  329.750000
# 2021-12-13  334.489990
# 2021-12-14  333.739990
# 2021-12-15  341.660004
#
# [2004 rows x 6 columns]

# %%
symbols = ['AAPL', 'MSFT', 'BRK-A']

data = web.DataReader(symbols, 'yahoo', start=start, end=end)

# %%
data['Close']
# Out:
# Symbols           AAPL        MSFT     BRK-A
# Date
# 2014-01-02   19.754642   37.160000  176320.0
# 2014-01-03   19.320715   36.910000  176336.0
# 2014-01-06   19.426071   36.130001  174500.0
# 2014-01-07   19.287144   36.410000  174195.0
# 2014-01-08   19.409286   35.759998  173284.0
# ...                ...         ...       ...
# 2021-12-09  174.559998  333.100006  428402.0
# 2021-12-10  179.449997  342.540009  435000.0
# 2021-12-13  175.740005  339.399994  437730.0
# 2021-12-14  174.330002  328.339996  446104.0
# 2021-12-15  179.300003  334.649994  443702.0
#
# [2004 rows x 3 columns]

# %%
start = datetime(1965, 1, 1)
end = datetime(2021,12, 15)
ylds = web.DataReader('IRLTLT01GBM156N', 'fred', start, end)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,4))
plt.plot(ylds);

# %%
# !pip install quandl
# Out:
# Collecting quandl
#   Downloading Quandl-3.7.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: six in c:\users\apala\anaconda3\lib\site-packages (from quandl) (1.15.0)
# Requirement already satisfied: requests>=2.7.0 in c:\users\apala\anaconda3\lib\site-packages (from quandl) (2.25.1)
# Requirement already satisfied: pandas>=0.14 in c:\users\apala\anaconda3\lib\site-packages (from quandl) (1.2.4)
# Requirement already satisfied: numpy>=1.8 in c:\users\apala\anaconda3\lib\site-packages (from quandl) (1.20.1)
# Requirement already satisfied: more-itertools in c:\users\apala\anaconda3\lib\site-packages (from quandl) (8.7.0)
# Requirement already satisfied: inflection>=0.3.1 in c:\users\apala\anaconda3\lib\site-packages (from quandl) (0.5.1)
# Requirement already satisfied: python-dateutil in c:\users\apala\anaconda3\lib\site-packages (from quandl) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\apala\anaconda3\lib\site-packages (from pandas>=0.14->quandl) (2021.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\apala\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\apala\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\apala\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\apala\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (2.10)
# Installing collected packages: quandl
# Successfully installed quandl-3.7.0

# %%
import yfinance as yf
symbol = 'FB'
ticker = yf.Ticker(symbol)

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.69-py2.py3-none-any.whl (26 kB)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.10.tar.gz (8.2 kB)
# Requirement already satisfied: numpy>=1.15 in c:\users\apala\anaconda3\lib\site-packages (from yfinance) (1.20.1)
# Requirement already satisfied: pandas>=0.24 in c:\users\apala\anaconda3\lib\site-packages (from yfinance) (1.2.4)
# Collecting requests>=2.26
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\apala\anaconda3\lib\site-packages (from yfinance) (4.6.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\apala\anaconda3\lib\site-packages (from pandas>=0.24->yfinance) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\apala\anaconda3\lib\site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\apala\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\apala\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\apala\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2021.10.8)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.10-py3-none-any.whl (39 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\apala\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.4)
# Building wheels for collected packages: multitasking
#   Building wheel for multitasking (setup.py): started
#   Building wheel for multitasking (setup.py): finished with status 'done'
#   Created wheel for multitasking: filename=multitasking-0.0.10-py3-none-any.whl size=8488 sha256=a369eb39c55faf74ce8728ccd9198f89b039c7d5af2f055e2f8ce10df2cad1c9
#   Stored in directory: c:\users\apala\appdata\local\pip\cache\wheels\21\c9\66\b41c847de65c7985db52ec21d59996841598b8b0e93f2b9500
# Successfully built multitasking
# Installing collected packages: charset-normalizer, requests, multitasking, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
# Successfully installed charset-normalizer-2.0.10 multitasking-0.0.10 requests-2.27.1 yfinance-0.1.69
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.9.1 requires ruamel-yaml, which is not installed.

# %%
pd.Series(ticker.info).head(20)
# Out:
# zip                                                                94025
# sector                                            Communication Services
# fullTimeEmployees                                                  68177
# longBusinessSummary    Meta Platforms, Inc. develops products that en...
# city                                                          Menlo Park
# phone                                                       650 543 4800
# state                                                                 CA
# country                                                    United States
# companyOfficers                                                       []
# website                                          https://investor.fb.com
# maxAge                                                                 1
# address1                                                1601 Willow Road
# industry                                  Internet Content & Information
# ebitdaMargins                                                    0.48748
# profitMargins                                                     0.3588
# grossMargins                                                      0.8085
# operatingCashflow                                            53618999296
# revenueGrowth                                                      0.351
# operatingMargins                                                  0.4179
# ebitda                                                       54758998016
# dtype: object

# %%
data = ticker.history(period='5d',interval='1m', start=None,end=None, actions=True, auto_adjust=True, back_adjust=False)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1944 entries, 2022-01-06 09:30:00-05:00 to 2022-01-12 15:59:00-05:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          1944 non-null   float64
#  1   High          1944 non-null   float64
#  2   Low           1944 non-null   float64
#  3   Close         1944 non-null   float64
#  4   Volume        1944 non-null   int64
#  5   Dividends     1944 non-null   int64
#  6   Stock Splits  1944 non-null   int64
# dtypes: float64(4), int64(3)
# memory usage: 121.5 KB

# %%
ticker.financials
# Out:
#                                            2020-12-31     2019-12-31  \
# Research Development                    18447000000.0  13600000000.0
# Effect Of Accounting Charges                     None           None
# Income Before Tax                       33180000000.0  24812000000.0
# Minority Interest                                None           None
# Net Income                              29146000000.0  18485000000.0
# Selling General Administrative          18155000000.0  15341000000.0
# Gross Profit                            69273000000.0  57927000000.0
# Ebit                                    32671000000.0  28986000000.0
# Operating Income                        32671000000.0  28986000000.0
# Other Operating Expenses                         None           None
# Interest Expense                                  NaN            NaN
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# Other Items                                      None           None
# Income Tax Expense                       4034000000.0   6327000000.0
# Total Revenue                           85965000000.0  70697000000.0
# Total Operating Expenses                53294000000.0  41711000000.0
# Cost Of Revenue                         16692000000.0  12770000000.0
# Total Other Income Expense Net            509000000.0  -4174000000.0
# Discontinued Operations                          None           None
# Net Income From Continuing Ops          29146000000.0  18485000000.0
# Net Income Applicable To Common Shares  29146000000.0  18485000000.0
#
#                                            2018-12-31     2017-12-31
# Research Development                    10273000000.0   7754000000.0
# Effect Of Accounting Charges                     None           None
# Income Before Tax                       25361000000.0  20594000000.0
# Minority Interest                                None           None
# Net Income                              22112000000.0  15934000000.0
# Selling General Administrative          11297000000.0   7242000000.0
# Gross Profit                            46483000000.0  35199000000.0
# Ebit                                    24913000000.0  20203000000.0
# Operating Income                        24913000000.0  20203000000.0
# Other Operating Expenses                         None           None
# Interest Expense                                  NaN     -6000000.0
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# Other Items                                      None           None
# Income Tax Expense                       3249000000.0   4660000000.0
# Total Revenue                           55838000000.0  40653000000.0
# Total Operating Expenses                30925000000.0  20450000000.0
# Cost Of Revenue                          9355000000.0   5454000000.0
# Total Other Income Expense Net            448000000.0    391000000.0
# Discontinued Operations                          None           None
# Net Income From Continuing Ops          22112000000.0  15934000000.0
# Net Income Applicable To Common Shares  22111000000.0  15920000000.0

# %%
ticker.options
# Out:
# ('2022-01-14',
#  '2022-01-21',
#  '2022-01-28',
#  '2022-02-04',
#  '2022-02-11',
#  '2022-02-18',
#  '2022-02-25',
#  '2022-03-18',
#  '2022-04-14',
#  '2022-05-20',
#  '2022-06-17',
#  '2022-07-15',
#  '2022-09-16',
#  '2023-01-20',
#  '2023-03-17',
#  '2023-06-16',
#  '2024-01-19',
#  '2026-02-21')

# %%
options.calls.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-9a431375fba6> in <module>
# ----> 1 options.calls.info()
#
# NameError: name 'options' is not defined
