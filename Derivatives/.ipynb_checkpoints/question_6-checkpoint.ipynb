# %%
from PIL import Image

# %%
img_a = Image.open('ex_a.png')
img_b = Image.open('ex_b.png')
img_c_d_cashflow = Image.open('ex_c_d_cashflow.png')
img_c_d_results = Image.open('ex_c_d_results.png')
img_e_cashflow = Image.open('ex_e_cashflow.png')
img_e_results = Image.open('ex_e_results.png')

# %% [markdown]
# ### 6a.

# %%
# You will find below the Excel Swap sheet screenshot, with defined rates for 1, 2, 3, 5, 7, 10 years tenor.
# The coupon payment conventions for the fixed leg is Act / 360.
# The Swap Rate is flat at 5% - which leads to interpolated rates of 5% between defined maturities.
# We assumed t0 as 08/12/2021.

# %%
img_a
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3372x818 at 0x1693BF0F580>

# %% [markdown]
# ### 6b.

# %%
# Below you will find the screenshot of the Excel Swap sheet with the requested inputs.
# The rates and terms in blue are interpolated values. The ones in black are pre-defined.
# You can see the final discount factor curve in the last column of the image.

# %%
img_b
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3501x825 at 0x1693C0D5250>

# %% [markdown]
# ### 6c. and 6d.

# %%
# To simplify the visualisation of the results, we merged the answer from 6c and 6d into the same spreadsheet.
# In order to do so, we used the same inputs from questions a and b in both questions:

## Main Assumptions:
## Rates: 1Y: 2.3%; 2Y: 2.6%; 3Y: 2.86%; 5Y: 3.03%; 7Y: 3.18%; 10Y: 3.25%
## Interpolation method: Linear
## Day count convention: Act / 360
## Valuation date: 07/12/2017
## Notional: 1.000.000,00 euros
## 1 year expiry
## 7 years maturity
## Fixed leg payments: semi-annual

# %%
# Cashflow and discount factor curve:

img_c_d_cashflow
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3112x850 at 0x1693C0F5970>

# %%
# Results:

img_c_d_results
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=428x633 at 0x1693F77A5B0>

# %%
# Comentaries on answers for C and D:

# Z(0, tn) is what is referred to as Z(T1) in question C. It is the discount factor until the expiry date of the option.
# Z(0, T) is Z(T2), which is the discount factor untiy the maturity of the swap.
# The forward rate is referred as 'Forward' in the image.
# The swap PV01 is referred as Annuity(T, tn).
# 'Receiver Value' and 'Payer Value' are self-explanatoy. They are the result considering all the inputs shown in the image.

# %% [markdown]
# ### 6e.

# %%
# In the image below you will see the pricing results when we add 1bp to every pre-defined swap rate:

img_e_results
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=427x636 at 0x1693F77A8B0>

# %%
#### HERE WE WILL DISCUSS HEDGING AND SHIT... ALEX, LET'S DO THIS TOGETHER
